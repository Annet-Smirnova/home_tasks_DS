# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# ## Це мій перший код
# буду експерементувати
#
# Мене звати **Ганна**

# %%
my_list=[8,20,50,40]
s='Smile'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
print (my_list)
# Out:
# [8, 20, 50, 40]

# %%
print (s)
# Out:
# Smile

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.cos(range(15)));
